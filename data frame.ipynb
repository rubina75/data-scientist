# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv(r"C:\Users\User\Downloads\imdb-top-1000 - imdb-top-1000.csv")

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes      Gross  \
# ...

# %%
movies.describe()
# Out:
#            Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# count  1000.000000  1000.000000  1.000000e+03  1.000000e+03  843.000000
# mean    122.891000     7.949300  2.736929e+05  1.282781e+08   77.971530
# std      28.093671     0.275491  3.273727e+05  2.011110e+08   12.376099
# min      45.000000     7.600000  2.508800e+04  1.305000e+03   28.000000
# 25%     103.000000     7.700000  5.552625e+04  5.012919e+06   70.000000
# 50%     119.000000     7.900000  1.385485e+05  3.953432e+07   79.000000
# 75%     137.000000     8.100000  3.741612e+05  1.615997e+08   87.000000
# max     321.000000     9.300000  2.343110e+06  9.366622e+08  100.000000

# %%
movies.describe(include=all)
movies
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 movies.describe(include=all)
#       2 movies
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   int64
#  9   Metascore      843 non-null    float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes      Gross  \
# ...

# %%
movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes      Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000       96.0

# %%
movies.tail()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 995  Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                   Giant          1956      201   Drama          7.6
# 997   From Here to Eternity          1953      118   Drama          7.6
# 998                Lifeboat          1944       97   Drama          7.6
# 999            The 39 Steps          1935       86   Crime          7.6
#
#              Director              Star1  No_of_Votes      Gross  Metascore
# 995     Blake Edwards     Audrey Hepburn       166544  679874270       76.0
# 996    George Stevens   Elizabeth Taylor        34075  195217415       84.0
# 997    Fred Zinnemann     Burt Lancaster        43374   30500000       85.0
# 998  Alfred Hitchcock  Tallulah Bankhead        26471  852142728       78.0
# 999  Alfred Hitchcock       Robert Donat        51853  302787539       93.0

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')
