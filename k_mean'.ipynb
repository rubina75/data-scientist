# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# import dataset
from sklearn import datasets
iris_data = iris.data
iris = datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
# df.head(2)
X_scaled = StandardScaler().fit_transform(df)

# %%
# apply K_mean
kmeans = KMeans(n_clusters=3)
kmeans.fit(iris_data)
iris['cluster']=kmeans.labels_
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# visualize the cluster
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'],c=kmeans.labels_,cmap = 'rainbow')
plt.show()

# %%
# standardize data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
# standardize data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
# Out:
# Explained variance  [0.72962445 0.22850762 0.03668922]

# %% [markdown]
# plt.scatter(principle_components [: , 0],principle_components[:, 2],c=kmeans.labels_,cmap = 'rainbow')
# plt.xlabel('pc1')
# plt.ylabel('pc2')
# plt.show()

# %%
print(principle_components.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 print(principle_components.shape)
#
# NameError: name 'principle_components' is not defined
