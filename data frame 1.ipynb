# %%
import pandas as pd
import numpy as np

# %%
cars=pd.read_csv(r"C:\Users\User\Downloads\Automobile - Automobile (1).csv")
cars
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
cars.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
movies = pd.read_csv(r"C:\Users\User\Downloads\imdb-top-1000 - imdb-top-1000.csv")
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes      Gross  \
# ...

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
no_meta=movies[movies['Metascore'].isna()]
print("Metascore null")
no_meta
# Out:
# Metascore null
#                       Series_Title Released_Year  Runtime      Genre  \
# 20                 Soorarai Pottru          2020      153      Drama
# 54       Ayla: The Daughter of War          2017      125  Biography
# 55                    Vikram Vedha          2017      147     Action
# 57                          Dangal          2016      161     Action
# 65                Taare Zameen Par          2007      165      Drama
# ..                             ...           ...      ...        ...
# 872  The Day the Earth Stood Still          1951       92      Drama
# 874                          Gilda          1946      110      Drama
# 899                      El cuerpo          2012      112    Mystery
# 909                      Celda 211          2009      113     Action
# 913                      Die Welle          2008      107      Drama
#
#      IMDB_Rating       Director           Star1  No_of_Votes      Gross  \
# ...

# %%
movies['Metascore'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Metascore, Length: 1000, dtype: bool

# %%
movies[movies['Metascore'].isna()]
# Out:
#                       Series_Title Released_Year  Runtime      Genre  \
# 20                 Soorarai Pottru          2020      153      Drama
# 54       Ayla: The Daughter of War          2017      125  Biography
# 55                    Vikram Vedha          2017      147     Action
# 57                          Dangal          2016      161     Action
# 65                Taare Zameen Par          2007      165      Drama
# ..                             ...           ...      ...        ...
# 872  The Day the Earth Stood Still          1951       92      Drama
# 874                          Gilda          1946      110      Drama
# 899                      El cuerpo          2012      112    Mystery
# 909                      Celda 211          2009      113     Action
# 913                      Die Welle          2008      107      Drama
#
#      IMDB_Rating       Director           Star1  No_of_Votes      Gross  \
# ...

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore]
# Index: []
